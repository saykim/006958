# %% [markdown]
# <a href="https://colab.research.google.com/github/saykim/006958/blob/master/30%EC%B4%88_%EC%88%98%EC%B2%98%EB%A6%AC%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%84%EC%B2%98%EB%A6%AC_%EC%B7%A8%ED%95%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import xlrd, xlsxwriter
import glob

# %%
#-*- coding:utf-8 -*-

# %% [markdown]
# ## 데이터(CSV) 붙이기

# %%
list =[]
for filename in os.listdir():
    if filename[-3:] == 'xls':
        list.append(filename)

# %%
list
# Out:
# ['20200518.xls',
#  '20200519.xls',
#  '20200520.xls',
#  '20200521.xls',
#  '20200522.xls',
#  '20200523.xls',
#  '20200524.xls']

# %%
#날짜를 파일명으로
name1 = list[0][4:8]
name2 = list[-1][4:8]

# %%
dfs=[]
for i in list:
    df = pd.read_csv(i, encoding='euc-kr', sep='\t', index_col=None)
    #df = pd.read_excel(i,sheet_name=0)
    dfs.append(df)
tdf = pd.concat(dfs, sort=False)

# %%
tdf
# Out:
#                        시각  RCS.AIT201.PV_AI  RCS.AIT204A.PV_AI  \
# 0     2020/05/18 00:00:16           1.49375            0.06250
# 1     2020/05/18 00:00:46           1.51875            0.07250
# 2     2020/05/18 00:01:16           1.49000            0.06125
# 3     2020/05/18 00:01:46           1.49250            0.06750
# 4     2020/05/18 00:02:16           1.53750            0.06250
# ...                   ...               ...                ...
# 2875  2020/05/24 23:57:51           1.69250            0.07125
# 2876  2020/05/24 23:58:21           1.69625            0.07250
# 2877  2020/05/24 23:58:51           1.69750            0.08250
# 2878  2020/05/24 23:59:21           1.70875            0.08125
# 2879  2020/05/24 23:59:51           1.71375            0.07500
#
#       RCS.AIT204B.PV_AI  RCS.AIT208A.PV_AI  RCS.AIT208B.PV_AI  \
# 0               0.00000           2.657375           6.069875
# 1               0.00000           2.658250           6.069000
# 2               0.00000           2.658250           6.070750
# 3               0.00000           2.659125           6.072500
# 4               0.00000           2.657375           6.073375
# ...                 ...                ...                ...
# 2875            3.57500           2.872625           6.103125
# 2876            3.65125           2.873500           6.102250
# 2877            3.65750           2.870875           6.104000
# 2878            3.60875           2.872625           6.105750
# 2879            3.53250           2.872625           6.109250
#
#       RCS.AIT302A.PV_AI  RCS.AIT302B.PV_AI  RCS.AIT302C.PV_AI  \
# 0              191.8125           168.0000           310.3125
# 1              193.1250           170.4375           309.7500
# 2              192.0000           171.0000           309.9375
# 3              191.8125           171.1875           310.8750
# 4              191.2500           171.1875           309.5625
# ...                 ...                ...                ...
# 2875           173.8125           174.1875           254.6250
# 2876           174.0000           174.7500           255.9375
# 2877           173.8125           174.5625           254.4375
# 2878           174.0000           174.1875           254.6250
# 2879           175.6875           175.3125           255.5625
#
#       RCS.AIT302D.PV_AI  ...  RCS10.엔비텍_TOTAL전력  RCS10.엔비텍_TOTAL무효전력  \
# 0              173.0625  ...                NaN                  NaN
# 1              172.8750  ...                NaN                  NaN
# 2              174.0000  ...                NaN                  NaN
# 3              173.8125  ...                NaN                  NaN
# 4              173.8125  ...                NaN                  NaN
# ...                 ...  ...                ...                  ...
# 2875           200.4375  ...                NaN                  NaN
# 2876           200.6250  ...                NaN                  NaN
# 2877           201.0000  ...                NaN                  NaN
# 2878           200.8125  ...                NaN                  NaN
# 2879           200.6250  ...                NaN                  NaN
#
#       RCS10.엔비텍_TOTAL피상전력  RCS10.엔비텍_주파수  RCS10.엔비텍_유효전력량  RCS10.엔비텍_무효전력량  \
# 0                     NaN            NaN              NaN              NaN
# 1                     NaN            NaN              NaN              NaN
# 2                     NaN            NaN              NaN              NaN
# 3                     NaN            NaN              NaN              NaN
# 4                     NaN            NaN              NaN              NaN
# ...                   ...            ...              ...              ...
# 2875                  NaN            NaN              NaN              NaN
# 2876                  NaN            NaN              NaN              NaN
# 2877                  NaN            NaN              NaN              NaN
# 2878                  NaN            NaN              NaN              NaN
# 2879                  NaN            NaN              NaN              NaN
#
#       RCS10.엔비텍_피상전력량  RCS10.M601A_TMR_OFF_PV_PH조교반기1  \
# 0                 NaN                             NaN
# 1                 NaN                             NaN
# 2                 NaN                             NaN
# 3                 NaN                             NaN
# 4                 NaN                             NaN
# ...               ...                             ...
# 2875              NaN                             NaN
# 2876              NaN                             NaN
# 2877              NaN                             NaN
# 2878              NaN                             NaN
# 2879              NaN                             NaN
#
#       RCS10.M601B_TMR_ON_SV_PH조교반기2  RCS10.M601B_TMR_OFF_PV_PH조교반기2
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# ...                             ...                             ...
# 2875                            NaN                             NaN
# 2876                            NaN                             NaN
# 2877                            NaN                             NaN
# 2878                            NaN                             NaN
# 2879                            NaN                             NaN
#
# [20153 rows x 1067 columns]

# %%
tdf['시각'] = pd.to_datetime(tdf['시각'])
tdf = tdf.set_index('시각')

# %%
tdf.head()
# Out:
#                      RCS.AIT201.PV_AI  RCS.AIT204A.PV_AI  RCS.AIT204B.PV_AI  \
# 시각
# 2020-05-18 00:00:16           1.49375            0.06250                0.0
# 2020-05-18 00:00:46           1.51875            0.07250                0.0
# 2020-05-18 00:01:16           1.49000            0.06125                0.0
# 2020-05-18 00:01:46           1.49250            0.06750                0.0
# 2020-05-18 00:02:16           1.53750            0.06250                0.0
#
#                      RCS.AIT208A.PV_AI  RCS.AIT208B.PV_AI  RCS.AIT302A.PV_AI  \
# 시각
# 2020-05-18 00:00:16           2.657375           6.069875           191.8125
# 2020-05-18 00:00:46           2.658250           6.069000           193.1250
# 2020-05-18 00:01:16           2.658250           6.070750           192.0000
# 2020-05-18 00:01:46           2.659125           6.072500           191.8125
# 2020-05-18 00:02:16           2.657375           6.073375           191.2500
#
#                      RCS.AIT302B.PV_AI  RCS.AIT302C.PV_AI  RCS.AIT302D.PV_AI  \
# 시각
# 2020-05-18 00:00:16           168.0000           310.3125           173.0625
# 2020-05-18 00:00:46           170.4375           309.7500           172.8750
# 2020-05-18 00:01:16           171.0000           309.9375           174.0000
# 2020-05-18 00:01:46           171.1875           310.8750           173.8125
# 2020-05-18 00:02:16           171.1875           309.5625           173.8125
#
#                      RCS.AIT302E.PV_AI  ...  RCS10.엔비텍_TOTAL전력  \
# 시각                                      ...
# 2020-05-18 00:00:16           218.4375  ...                NaN
# 2020-05-18 00:00:46           218.4375  ...                NaN
# 2020-05-18 00:01:16           218.6250  ...                NaN
# 2020-05-18 00:01:46           219.9375  ...                NaN
# 2020-05-18 00:02:16           219.3750  ...                NaN
#
#                      RCS10.엔비텍_TOTAL무효전력  RCS10.엔비텍_TOTAL피상전력  RCS10.엔비텍_주파수  \
# 시각
# 2020-05-18 00:00:16                  NaN                  NaN            NaN
# 2020-05-18 00:00:46                  NaN                  NaN            NaN
# 2020-05-18 00:01:16                  NaN                  NaN            NaN
# 2020-05-18 00:01:46                  NaN                  NaN            NaN
# 2020-05-18 00:02:16                  NaN                  NaN            NaN
#
#                      RCS10.엔비텍_유효전력량  RCS10.엔비텍_무효전력량  RCS10.엔비텍_피상전력량  \
# 시각
# 2020-05-18 00:00:16              NaN              NaN              NaN
# 2020-05-18 00:00:46              NaN              NaN              NaN
# 2020-05-18 00:01:16              NaN              NaN              NaN
# 2020-05-18 00:01:46              NaN              NaN              NaN
# 2020-05-18 00:02:16              NaN              NaN              NaN
#
#                      RCS10.M601A_TMR_OFF_PV_PH조교반기1  \
# 시각
# 2020-05-18 00:00:16                             NaN
# 2020-05-18 00:00:46                             NaN
# 2020-05-18 00:01:16                             NaN
# 2020-05-18 00:01:46                             NaN
# 2020-05-18 00:02:16                             NaN
#
#                      RCS10.M601B_TMR_ON_SV_PH조교반기2  \
# 시각
# 2020-05-18 00:00:16                            NaN
# 2020-05-18 00:00:46                            NaN
# 2020-05-18 00:01:16                            NaN
# 2020-05-18 00:01:46                            NaN
# 2020-05-18 00:02:16                            NaN
#
#                      RCS10.M601B_TMR_OFF_PV_PH조교반기2
# 시각
# 2020-05-18 00:00:16                             NaN
# 2020-05-18 00:00:46                             NaN
# 2020-05-18 00:01:16                             NaN
# 2020-05-18 00:01:46                             NaN
# 2020-05-18 00:02:16                             NaN
#
# [5 rows x 1066 columns]

# %% [markdown]
# ### RO변환

# %%
tdf_ro = tdf[["RCS.AIT101.PV_AI",
                "RCS.AIT204B.PV_AI",
                "RCS.TIT201.PV_AI",
                "주처리.AIE304A.PV_AI",
                "주처리.AIE304B.PV_AI",
                "주처리.AIE304C.PV_AI",
                "주처리.AIE304D.PV_AI",
                "주처리.AIE304E.PV_AI",
                "주처리.AIE304F.PV_AI",
                "주처리.FIT314A.PV_AI",
                "주처리.FIT314B.PV_AI",
                "주처리.FIT324A.PV_AI",
                "주처리.FIT324B.PV_AI",
                "주처리.FIT334A.PV_AI",
                "주처리.FIT334B.PV_AI",
                "주처리.FIT344A.PV_AI",
                "주처리.FIT344B.PV_AI",
                "주처리.FIT354A.PV_AI",
                "주처리.FIT354B.PV_AI",
                "주처리.FIT364A.PV_AI",
                "주처리.FIT364B.PV_AI",
                "주처리.PIT314A.PV_AI",
                "주처리.PIT314B.PV_AI",
                "주처리.PIT314C.PV_AI",
                "주처리.PIT324A.PV_AI",
                "주처리.PIT324B.PV_AI",
                "주처리.PIT324C.PV_AI",
                "주처리.PIT334A.PV_AI",
                "주처리.PIT334B.PV_AI",
                "주처리.PIT334C.PV_AI",
                "주처리.PIT344A.PV_AI",
                "주처리.PIT344B.PV_AI",
                "주처리.PIT344C.PV_AI",
                "주처리.PIT354A.PV_AI",
                "주처리.PIT354B.PV_AI",
                "주처리.PIT354C.PV_AI",
                "주처리.PIT364A.PV_AI",
                "주처리.PIT364B.PV_AI",
                "주처리.PIT364C.PV_AI",
                "RCS.AIT1101A.PV_AI",
                "RCS.AIT1101B.PV_AI"
]]

# %%
tdf_ro = tdf_ro.rename(columns={"RCS.AIT101.PV_AI":"증설탁도",
                                "RCS.AIT204B.PV_AI":"전처리수SDI",
                                "RCS.TIT201.PV_AI":"원수저류조후단온도계",
                                "주처리.AIE304A.PV_AI":"A전도도",
                                "주처리.AIE304B.PV_AI":"B전도도",
                                "주처리.AIE304C.PV_AI":"C전도도",
                                "주처리.AIE304D.PV_AI":"D전도도",
                                "주처리.AIE304E.PV_AI":"E전도도",
                                "주처리.AIE304F.PV_AI":"F전도도",
                                "주처리.FIT314A.PV_AI":"A생산량",
                                "주처리.FIT314B.PV_AI":"A농축수량",
                                "주처리.FIT324A.PV_AI":"B생산량",
                                "주처리.FIT324B.PV_AI":"B농축수량",
                                "주처리.FIT334A.PV_AI":"C생산량",
                                "주처리.FIT334B.PV_AI":"C농축수량",
                                "주처리.FIT344A.PV_AI":"D생산량",
                                "주처리.FIT344B.PV_AI":"D농축수량",
                                "주처리.FIT354A.PV_AI":"E생산량",
                                "주처리.FIT354B.PV_AI":"E농축수량",
                                "주처리.FIT364A.PV_AI":"F생산량",
                                "주처리.FIT364B.PV_AI":"F농축수량",
                                "주처리.PIT314A.PV_AI":"A유입압",
                                "주처리.PIT314B.PV_AI":"A생산압",
                                "주처리.PIT314C.PV_AI":"A농축압",
                                "주처리.PIT324A.PV_AI":"B유입압",
                                "주처리.PIT324B.PV_AI":"B생산압",
                                "주처리.PIT324C.PV_AI":"B농축압",
                                "주처리.PIT334A.PV_AI":"C유입압",
                                "주처리.PIT334B.PV_AI":"C생산압",
                                "주처리.PIT334C.PV_AI":"C농축압",
                                "주처리.PIT344A.PV_AI":"D유입압",
                                "주처리.PIT344B.PV_AI":"D생산압",
                                "주처리.PIT344C.PV_AI":"D농축압",
                                "주처리.PIT354A.PV_AI":"E유입압",
                                "주처리.PIT354B.PV_AI":"E생산압",
                                "주처리.PIT354C.PV_AI":"E농축압",
                                "주처리.PIT364A.PV_AI":"F유입압",
                                "주처리.PIT364B.PV_AI":"F생산압",
                                "주처리.PIT364C.PV_AI":"F농축압",
                                "RCS.AIT1101A.PV_AI":"RO유입수전도도",
                                "RCS.AIT1101B.PV_AI":"RO유입수온도" 
                                })

# %% [markdown]
# > 유입량 및 차압 계산

# %%
#유입량 추출
tdf_ro['A유입량'] = tdf_ro['A생산량'] + tdf_ro['A농축수량']
tdf_ro['B유입량'] = tdf_ro['B생산량'] + tdf_ro['B농축수량']
tdf_ro['C유입량'] = tdf_ro['C생산량'] + tdf_ro['C농축수량']
tdf_ro['D유입량'] = tdf_ro['D생산량'] + tdf_ro['D농축수량']
tdf_ro['E유입량'] = tdf_ro['E생산량'] + tdf_ro['E농축수량']
tdf_ro['F유입량'] = tdf_ro['F생산량'] + tdf_ro['F농축수량']


#차압 추출
tdf_ro['A차압'] = tdf_ro['A유입압'] - tdf_ro['A농축압']
tdf_ro['B차압'] = tdf_ro['B유입압'] - tdf_ro['B농축압']
tdf_ro['C차압'] = tdf_ro['C유입압'] - tdf_ro['C농축압']
tdf_ro['D차압'] = tdf_ro['D유입압'] - tdf_ro['D농축압']
tdf_ro['E차압'] = tdf_ro['E유입압'] - tdf_ro['E농축압']
tdf_ro['F차압'] = tdf_ro['F유입압'] - tdf_ro['F농축압']

# %%
tdf_ro = tdf_ro[["증설탁도",
                "전처리수SDI",
                "원수저류조후단온도계",
                "A전도도",
                "B전도도",
                "C전도도",
                "D전도도",
                "E전도도",
                "F전도도",
                "A생산량",
                "A농축수량",
                "B생산량",
                "B농축수량",
                "C생산량",
                "C농축수량",
                "D생산량",
                "D농축수량",
                "E생산량",
                "E농축수량",
                "F생산량",
                "F농축수량",
                "A유입압",
                "A생산압",
                "A농축압",
                "B유입압",
                "B생산압",
                "B농축압",
                "C유입압",
                "C생산압",
                "C농축압",
                "D유입압",
                "D생산압",
                "D농축압",
                "E유입압",
                "E생산압",
                "E농축압",
                "F유입압",
                "F생산압",
                "F농축압",
                "A유입량",
                "B유입량",
                "C유입량",
                "D유입량",
                "E유입량",
                "F유입량",
                "A차압",
                "B차압",
                "C차압",
                "D차압",
                "E차압",
                "F차압",
                "RO유입수전도도",
                "RO유입수온도"
                    ]]

# %%
ro = tdf_ro.resample(rule='1h').median()
ro.to_excel('RO전처리_new_{}_{}.xlsx'.format(name1,name2)) #파일병에서 '날짜 변경 필요'

# %% [markdown]
# ### AF 추가하기

# %%
tdf_af = tdf[["스트레이너.PIT203A1.PV_AI",
                "스트레이너.PIT203A2.PV_AI",
                "스트레이너.PIT203B1.PV_AI",
                "스트레이너.PIT203B2.PV_AI",
                "스트레이너.PIT203C1.PV_AI",
                "스트레이너.PIT203C2.PV_AI",
                "스트레이너.PIT203D1.PV_AI",
                "스트레이너.PIT203D2.PV_AI",
                "전처리.FIT204A.PVAI",
                "전처리.FIT204C.PVAI",
                "전처리.FIT204E.PVAI",
                "전처리.FIT204G.PVAI",
]]

# %%
tdf_af = tdf_af.rename(columns={"스트레이너.PIT203A1.PV_AI":"A/F A_in",
                                "스트레이너.PIT203A2.PV_AI":"A/F A_out",
                                "스트레이너.PIT203B1.PV_AI":"A/F B_in",
                                "스트레이너.PIT203B2.PV_AI":"A/F B_out",
                                "스트레이너.PIT203C1.PV_AI":"A/F C_in",
                                "스트레이너.PIT203C2.PV_AI":"A/F C_out",
                                "스트레이너.PIT203D1.PV_AI":"A/F D_in",
                                "스트레이너.PIT203D2.PV_AI":"A/F D_out",
                                "전처리.FIT204A.PVAI":"전처리.FIT204A.PVAI",
                                "전처리.FIT204C.PVAI":"전처리.FIT204C.PVAI",
                                "전처리.FIT204E.PVAI":"전처리.FIT204E.PVAI",
                                "전처리.FIT204G.PVAI":"전처리.FIT204G.PVAI",
})

# %% [markdown]
# > AF DP 구하기

# %%
tdf_af['A/F_A_DP'] = tdf_af['A/F A_in'] - tdf_af['A/F A_out']
tdf_af['A/F_B_DP'] = tdf_af['A/F B_in'] - tdf_af['A/F B_out']
tdf_af['A/F_C_DP'] = tdf_af['A/F C_in'] - tdf_af['A/F C_out']
tdf_af['A/F_D_DP'] = tdf_af['A/F D_in'] - tdf_af['A/F D_out']

# %%
tdf_af = tdf_af[["A/F A_in",
                "A/F A_out",
                "A/F B_in",
                "A/F B_out",
                "A/F C_in",
                "A/F C_out",
                "A/F D_in",
                "A/F D_out",
                "A/F_A_DP",
                "A/F_B_DP",
                "A/F_C_DP",
                "A/F_D_DP",
                "전처리.FIT204A.PVAI",
                "전처리.FIT204C.PVAI",
                "전처리.FIT204E.PVAI",
                "전처리.FIT204G.PVAI"
]]

# %%
af = tdf_af.resample(rule='30min').median()
af.to_excel('df_{}_{}_strainer_30min_median.xlsx'.format(name1,name2)) #파일병에서 '날짜 변경 필요'

# %% [markdown]
# ### 질소농도

# %%
tdf_no = tdf[["RCS.AIT1102A.PV_AI",
            "RCS.AIT1102B.PV_AI",
            "RCS.AIT1103A.PV_AI",
            "RCS.AIT1103B.PV_AI",
            "RCS.AIT1104A.PV_AI",
            "RCS.AIT1104B.PV_AI"
            ]]

# %%
tdf_no = tdf_no.rename(columns={"RCS.AIT1102A.PV_AI":"농폐수처리조_NH4농도",
                                "RCS.AIT1102B.PV_AI":"농폐수처리조_NO3농도",
                                "RCS.AIT1103A.PV_AI":"탈질조후단_NH4농도",
                                "RCS.AIT1103B.PV_AI":"탈질조후단_NO3농도",
                                "RCS.AIT1104A.PV_AI":"질산화조후단_NH4농도",
                                "RCS.AIT1104B.PV_AI":"질산화조후단_NO3농도"
                                })

# %%
no_original = tdf_no

no_1h = tdf_no.resample(rule='1h').median()
no_1h.to_excel('no_1h_{}_{}.xlsx'.format(name1,name2)) #파일병에서 '날짜 변경 필요'

# %% [markdown]
# ### 농축폐수

# %%
tdf_ndw = tdf[["농축폐수.압력.PT801D.PV",
"농축폐수.압력.PT801C.PV",
"농축폐수.압력.PT801B.PV",
"농축폐수.압력.PT801A.PV",
"농축폐수.압력.PT701D.PV",
"농축폐수.압력.PT701C.PV",
"농축폐수.압력.PT701B.PV",
"농축폐수.압력.PT701A.PV",
]]

# %%
tdf_ndw = tdf_ndw.rename(columns={"농축폐수.압력.PT801D.PV":"질산화조#4",
"농축폐수.압력.PT801C.PV":"질산화조#3",
"농축폐수.압력.PT801B.PV":"질산화조#2",
"농축폐수.압력.PT801A.PV":"질산화조#1",
"농축폐수.압력.PT701D.PV":"탈질조#4",
"농축폐수.압력.PT701C.PV":"탈질조#3",
"농축폐수.압력.PT701B.PV":"탈질조#2",
"농축폐수.압력.PT701A.PV":"탈질조#1"
})

# %%
ndw = tdf_ndw.resample(rule='1h').median()
ndw.to_excel('농축폐수_{}_{}_1h.xlsx'.format(name1,name2)) #파일병에서 '날짜 변경 필요'

# %% [markdown]
# # 전체 유입량

# %%
tdf_volume = tdf[["RCS.FIT101A.적산값",
"RCS.FIT101B.적산값",
"RCS.FIT101C.적산값"
]]

# %%
tdf_volume = tdf_volume.rename(columns={"RCS.FIT101A.적산값":"금촌기존",
"RCS.FIT101B.적산값":"금촌증설",
"RCS.FIT101C.적산값":"운정"
})

# %%
volume = tdf_volume.resample(rule='d').agg(['min', 'max'])
volume.to_excel("df_total_{}_{}_volume.xlsx".format(name1,name2)) #파일병에서 '날짜 변경 필요'
